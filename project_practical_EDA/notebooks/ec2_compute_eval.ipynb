# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data\ec2_cpu_utilization_24ae8d.csv')

# %%
data.head()
# Out:
#              timestamp  value
# 0  2014-02-14 14:30:00  0.132
# 1  2014-02-14 14:35:00  0.134
# 2  2014-02-14 14:40:00  0.134
# 3  2014-02-14 14:45:00  0.134
# 4  2014-02-14 14:50:00  0.134

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4032 entries, 0 to 4031
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  4032 non-null   object
#  1   value      4032 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 63.1+ KB

# %%
data.describe()
# Out:
#              value
# count  4032.000000
# mean      0.126303
# std       0.094813
# min       0.066000
# 25%       0.132000
# 50%       0.134000
# 75%       0.134000
# max       2.344000

# %%
sample = data.iloc[1:100]
sample.index = range(1,100)

# %%
sample.head()
# Out:
#              timestamp  value
# 1  2014-02-14 14:35:00  0.134
# 2  2014-02-14 14:40:00  0.134
# 3  2014-02-14 14:45:00  0.134
# 4  2014-02-14 14:50:00  0.134
# 5  2014-02-14 14:55:00  0.134

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 1 to 99
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  99 non-null     object
#  1   value      99 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %%
plt.plot(sample['timestamp'], sample['value'])
plt.xlabel('Timestamp')
plt.ylabel('CPU Utilization')
plt.title('CPU Utilization Over Time')
plt.show()
